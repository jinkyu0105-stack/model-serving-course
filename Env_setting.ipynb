# %%
# !pwd
# Out:
# /home/onegem/work/model-serving-course

# %%
import sys
print(f"Python 경로:{sys.executable}")
# Out:
# Python 경로:/home/onegem/work/model-serving-course/.venv_jk/bin/python

# %%
# !which python
# Out:
# /home/onegem/work/model-serving-course/.venv_jk/bin/python

# %% [markdown]
# ### requirements.txt 생성

# %%
# %%writefile requirements.txt
# # ===== Core =====
# torch>=2.1.0,<2.5.0
# torchvision>=0.16.0,<0.20.0
#
# # ===== API =====
# fastapi==0.115.0
# uvicorn[standard]==0.30.0
# pydantic>=2.0.0,<3.0.0
#
# # ===== Frontend =====
# streamlit==1.38.0
#
# # ===== Utilities =====
# requests>=2.31.0,<3.0.0
# pillow>=10.0.0
# python-multipart>=0.0.6
# Out:
# Writing requirements.txt

# %% [markdown]
# ### 적혀 있는 목록과 버전대로 설치 시작

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 9.6 MB/s eta 0:00:00
# ...
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 48.7 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 MB 635.4 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 64.0 MB/s eta 0:00:00:00:0100:01
# ...

# %% [markdown]
# ### 설치 확인

# %%
import torch
import fastapi
import streamlit

print(f"PyTorch:   {torch.__version__}")
print(f"FastAPI:   {fastapi.__version__}")
print(f"Streamlit: {streamlit.__version__}")
# Out:
# PyTorch:   2.4.1+cu121
# FastAPI:   0.115.0
# Streamlit: 1.38.0

# %% [markdown]
# 원래는 이렇게 설치 해야지 GPU 버전으로 잡히는데 요즘엔 알아서 된다고 함.
#
# `pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121`

# %% [markdown]
# ### pip freeze는 하위 의존성 까지 모두 포함한다.
# 보다 정밀한 재현이 가능하다. 하지만 목록이 너무 길어서 가독성이 떨어진다.
# 그래서 실무에서는 두 가지를 병행해서 사용한다.
# - `requirements.txt` - 사람이 직접 관리
# - `requirements_freeze.txt` - 정밀 재현용

# %%
# !pip freeze > requirements_freeze.txt
# Out:
# cat: requirementes_freeze.txt: No such file or directory

# %%
# !cat requirements_freeze.txt
# Out:
# altair==5.5.0
# annotated-types==0.7.0
# anyio==4.13.0
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# arrow==1.4.0
# asttokens==3.0.1
# async-lru==2.3.0
# attrs==26.1.0
# babel==2.18.0
# beautifulsoup4==4.14.3
# bleach==6.3.0
# blinker==1.9.0
# cachetools==5.5.2
# certifi==2026.2.25
# cffi==2.0.0
# charset-normalizer==3.4.6
# click==8.3.1
# comm==0.2.3
# debugpy==1.8.20
# decorator==5.2.1
# defusedxml==0.7.1
# executing==2.2.1
# fastapi==0.115.0
# fastjsonschema==2.21.2
# filelock==3.25.2
# fqdn==1.5.1
# fsspec==2026.2.0
# gitdb==4.0.12
# GitPython==3.1.46
# h11==0.16.0
# httpcore==1.0.9
# httptools==0.7.1
# httpx==0.28.1
# idna==3.11
# ipykernel==7.2.0
# ipython==9.11.0
# ipython_pygments_lexers==1.1.1
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.6
# json5==0.13.0
# jsonpointer==3.1.1
# jsonschema==4.26.0
# jsonschema-specifications==2025.9.1
# jupyter-events==0.12.0
# jupyter-lsp==2.3.0
# jupyter_client==8.8.0
# jupyter_core==5.9.1
# jupyter_server==2.17.0
# ...

# %% [markdown]
# ### 폴더 구조 미리 만들기

# %%
import os

folders = [
    "models",          # 저장된 모델 파일 (.pth, .onnx 등)
    "app",             # FastAPI 애플리케이션 코드
    "frontend",        # Streamlit 프론트엔드 코드
    "notebooks",       # 주피터 노트북 (지금 이 파일)
    "data",            # 샘플 데이터
    "tests",           # 테스트 코드
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✅{folder}/ 생성 완료")
# Out:
# ✅models/ 생성 완료
# ✅app/ 생성 완료
# ✅frontend/ 생성 완료
# ✅notebooks/ 생성 완료
# ✅data/ 생성 완료
# ✅tests/ 생성 완료

# %% [markdown]
# ### .gitignore 작성

# %%
# %%writefile .gitignore
# # 가상환경
# .venv_jk/
#
# # Python 캐시
# __pycache__/
# *.pyc
# *.pyo
#
# # 모델 파일 (용량이 크므로 Git에 포함하지 않음)
# models/*.pth
# models/*.onnx
# models/*.pt
#
# # 주피터 체크포인트
# .ipynb_checkpoints/
#
# # OS 파일
# .DS_Store
# Thumbs.db
# Out:
# Writing .gitignore

# %%
# 생성 확인
# !cat .gitignore
# Out:
# # 가상환경
# .venv_jk/
#
# # Python 캐시
# __pycache__/
# *.pyc
# *.pyo
#
# # 모델 파일 (용량이 크므로 Git에 포함하지 않음)
# models/*.pth
# models/*.onnx
# models/*.pt
#
# # 주피터 체크포인트
# .ipynb_checkpoints/
#
# # OS 파일
# .DS_Store
# Thumbs.db
